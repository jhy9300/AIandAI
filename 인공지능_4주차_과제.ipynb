# %% [markdown]
# <a href="https://colab.research.google.com/github/jhy9300/AIandAI/blob/master/4%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
# - 용어 정리
# - 딥러닝 강의 클론 코딩
# - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성 하세요.
#
# * 2문장 이상 작성 해 주세요.
# * 주제(단어)와 크게 벗어나지만 않는다면 정답처리 됩니다.
# * 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다. (기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해 주세요.)

# %% [markdown]
# __(예시)__
# ### 심층 신경망
# : 입력층과 출력층 사이에 여러 개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 신층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에서 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# : 1943년 워랜 맥컬록과 월터 피츠는 뇌의 신경세포를 이진 출력을 내는 논리로 표현한 맥컬럭-피츠(MCP)라 불리는 뇌 세포의 개념을 정립했다. 맥컬록과 월터 피츠가 제시한 MCP 뉴런은 우선 수상돌기에서 복수의 화학적 신호를 받아서 세포체를 통해 통합해 전기 신호로 변경한다. 이후 통합한 전기신호가 특정 임계치를 넘는다면 축색돌기를 통해 다시 화학신호로 바꾸어 내보내는 간단한 구조를 갖고있다.
#
# ### 퍼셉트론
# : 위의 MCP뉴런 모델을 기반으로 프랭크 로젠 블렛이 제시한 학습개념이다. 퍼셉트론 학습개념을 간단하게 표현하면 입력 값들을 받아 각각의 가중치를 적용하고 합산한 값을 출력으로 반환한다.(가중치는 뉴런의 출력 신호의 유무를 결정하기 위해 입력 값에 곱하는 계수이다.) 이 학습개념은 학습을 통해 최적의 가중치를 구하는 알고리즘으로 가중치는 처음에 무작위 값이지만 학습을 통해 일정한 값으로 수렴한다.
#
# ### 역전파
# : XOR문제를 해결하기 위해 다층 퍼셉트론을 제시하였으나, 다층 퍼셉트론 또한 문제가 있었다. 파라미터의 개수가 많아지면서 적절한 가중치와 편향을 구하는 것이 어렵게 되었던 것이다. 이를 해결하고자 제프리 힌튼이 역전파 알고리즘을 제시하였다. 역전파 알고리즘은 출력값과 지도 데이터 사이에 제시하였다. 역전파 알고리즘은 출력값과 지도 데이터 사이에 생기는 '오차'를 이용하여 출력층에서 입력층으로 즉, 퍼셉트론 학습방향의 역방향으로 가중치를 조정하는 것이다. 이는 다층 퍼셉트론에서 가중치를 효율적으로 조정하는데 매우 유용하다. 물론 역전파 역시도 단점이 있었는데 이는 기울기 제시하였다. 역전파 알고리즘은 출력값과 지도 데이터 사이에 제시하였다. 역전파 알고리즘은 출력값과 지도 데이터 사이에 생기는 '오차'를 이용하여 출력층에서 입력층으로 즉, 퍼셉트론 학습방향의 역방향으로 가중치를 조정하는 것이다. 이는 다층 퍼셉트론에서 가중치를 효율적으로 조정하는데 매우 유용하다.
#
# ### 강화학습
# : 어떤 환경 안에서 존재하는 에이전트가 현재의 상태를 인식하여, 선택 가능한 행동들 중 보상을 최대화하려는 의사결정전략 및 학습과정이다. 이전의 학습과정과 다른 점은 강화학습은 지도학습처럼 정답을 제공받지 않고 비지도학습처럼 데이터를 제공받지 않은 채 학습한다는 것이다. 강화 학습에서 다루는 '환경'은 주로 마르코프 결정 과정(Markov decision process)로 제시된다.
#
# ### 과적합
# : 머신러닝에서 주어진 학습데이터를 너무 과하게 학습하는 것을 말한다. 학습데이터는 실제 데이터의 부분인데 그 부분만을 가지고 과하게 학습하기에 학습데이터 상에서는 오차가 감소하지만, 실제데이터 상에서는 오차가 증가하는 경향이 있다.
#
# ### 차원의 저주
# : 일반적으로 데이터가 많다면  학습하기가 수월하다고 생각된다. 하지만 머신러닝에서는 데이터가 너무 많은 정보(차원)를 담고 있으면 유용한 학습모델을 세우는 데는 이 차원의 크기가 오히려 방해하게 된다. 이를 차원의 저주라고 말하며, KNN 알고리즘에게는 아주 치명적인 영향을 준다. 차원이 증가함에 따라 오히려 근접한 라벨이 멀어지게 되는 것이다. 이 해결방법으로는 데이터를 한번 정제(차원 축소)하는 방법이 있다.
#
#
#
# cf. 모든 서술은 강의 내용을 바탕으로 하였으며 '과적합'과 '차원의 저주'는 위키백과 글을 참고하여 작성하였습니다.

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15 부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
#
# * 하나의 코드셀에 해당 코드를 한번에 다 적어서 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# *__주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F0cceeed0-0235-4b0f-af88-0b8c377d5b4b%2F_2020-06-09__9.35.23.png?table=block&id=88fd8912-9356-49a4-9fda-a1a63fe96ea9&width=2870&cache=v2)

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 1
y = 0
w= tf.random.normal([1],0,1)

import math
def sigmoid(x):
  return 1/(1 + math.exp(-x))

output = sigmoid(x * w)
print(output)

for i in range(1000):
  output = sigmoid(x*w)
  error = y - output
  w = w + x * 0.1 * error

  if i % 100 ==99:
    print('학습 횟수:',i,'Error:',error,'예측 결과:',output)
# Out:
# 0.47477188589261
# 학습 횟수: 99 Error: -0.10010598284299604 예측 결과: 0.10010598284299604
# 학습 횟수: 199 Error: -0.05178399422833116 예측 결과: 0.05178399422833116
# 학습 횟수: 299 Error: -0.034590451977903586 예측 결과: 0.034590451977903586
# 학습 횟수: 399 Error: -0.02588962752851373 예측 결과: 0.02588962752851373
# 학습 횟수: 499 Error: -0.020658699939863617 예측 결과: 0.020658699939863617
# 학습 횟수: 599 Error: -0.017174253993457355 예측 결과: 0.017174253993457355
# 학습 횟수: 699 Error: -0.014689506449480992 예측 결과: 0.014689506449480992
# 학습 횟수: 799 Error: -0.012829497265431342 예측 결과: 0.012829497265431342
# 학습 횟수: 899 Error: -0.011385568271837804 예측 결과: 0.011385568271837804
# 학습 횟수: 999 Error: -0.010232493309882492 예측 결과: 0.010232493309882492

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32 부분__)에 나오는 순전파 & 역전파 계산에 대한 문제 입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
#
# (1) 학습률이 0.2 일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2 일 경우 출력층의 노드값 : 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?  0.1 입니다.
